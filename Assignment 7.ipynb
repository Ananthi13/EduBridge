# %% [markdown]
# Exercise problems:
#
# read the data from given url to DataFrame as sales_data https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv
#
# Q1.Rename The column name with valid format: oldname:Order ID,Product,Quantity Ordered,Price Each,Order Date,Purchase Address newname:Order_ID,Product,Quantity_Ordered,Price_Each,Order_Date,Purchase_Address
#
# Q2.insert new column as order_price compute order_price =Price_Each*Quantity_Ordered
#
# Q3.Delete the column Purchase_Address
#
# Q4.insert new row data as at last 100001,OnePhone,1,600, 01/22/19 21:25,600
#
# Q5.Gruopby Product and apply the aggregate function min,max,mean on order_price
#
# read the data from given url to DataFrame as sales_data https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv
#
# read the data from given url to DataFrame as sales_data https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv

# %%
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv'
data=pd.read_csv(url)
data
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %% [markdown]
# Q1.Rename The column name with valid format: oldname:Order ID,Product,Quantity Ordered,Price Each,Order Date,Purchase Address newname:Order_ID,Product,Quantity_Ordered,Price_Each,Order_Date,Purchase_Address

# %%
data.columns=['Order_ID','Product','Quantity_Ordered','Price_Each','Order_Date','Purchase_Address']
data
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order_Date                       Purchase_Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order_Date                       Purchase_Address
# ...

# %%
data.isna().sum()
# Out:
# Order_ID            26
# Product             26
# Quantity_Ordered    26
# Price_Each          26
# Order_Date          26
# Purchase_Address    26
# dtype: int64

# %%
data.dropna(inplace=True)
data.isna().sum()
# Out:
# Order_ID            0
# Product             0
# Quantity_Ordered    0
# Price_Each          0
# Order_Date          0
# Purchase_Address    0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
#       Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 875     142071     AA Batteries (4-pack)                 1        3.84
# 1102  Order ID                   Product  Quantity Ordered  Price Each
# 1194  Order ID                   Product  Quantity Ordered  Price Each
# 1897  Order ID                   Product  Quantity Ordered  Price Each
# 2463  Order ID                   Product  Quantity Ordered  Price Each
# 3115  Order ID                   Product  Quantity Ordered  Price Each
# 3247  Order ID                   Product  Quantity Ordered  Price Each
# 3612  Order ID                   Product  Quantity Ordered  Price Each
# 3623  Order ID                   Product  Quantity Ordered  Price Each
# 4126    145143  Lightning Charging Cable                 1       14.95
# 4901  Order ID                   Product  Quantity Ordered  Price Each
# 5593  Order ID                   Product  Quantity Ordered  Price Each
# ...

# %%
data=data[~(data['Price_Each']=='Price Each')]
data
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order_Date                       Purchase_Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %% [markdown]
# Q2.insert new column as order_price compute order_price =Price_Each*Quantity_Ordered

# %%
data['order_price']=data['Price_Each'].astype(float)*data['Quantity_Ordered'].astype(float)
data
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# ...

# %% [markdown]
# Q3.Delete the column Purchase_Address

# %%
del data['Purchase_Address']
data
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order_Date  order_price
# 0     01/22/19 21:25       700.00
# 1     01/28/19 14:15        14.95
# 2     01/17/19 13:33        23.98
# ...

# %% [markdown]
# Q4.insert new row data as at last 100001,OnePhone,1,600, 01/22/19 21:25,600

# %%
data.columns
# Out:
# Index(['Order_ID', 'Product', 'Quantity_Ordered', 'Price_Each', 'Order_Date',
#        'order_price'],
#       dtype='object')

# %%
data.append({'Order_ID':100001, 'Product':'OnePhone','Quantity_Ordered':1,'Price_Each':600,'Order_Date':'01/22/19 21:25','order_price':600},ignore_index=Tru

# %% [markdown]
# Q5.Groupby Product and apply the aggregate function min,max,mean on order_price

# %%
data.groupby('Product').agg({'order_price':[np.min, np.mean, np.max]})
# Out:
#                            order_price
#                                   amin         mean     amax
# Product
# 20in Monitor                    109.99   111.022770   219.98
# 27in 4K Gaming Monitor          389.99   389.990000   389.99
# 27in FHD Monitor                149.99   150.348828   299.98
# 34in Ultrawide Monitor          379.99   381.204026   759.98
# AA Batteries (4-pack)             3.84     5.266603    19.20
# AAA Batteries (4-pack)            2.99     4.410388    20.93
# Apple Airpods Headphones        150.00   150.927070   300.00
# Bose SoundSport Headphones       99.99   100.447271   199.98
# Flatscreen TV                   300.00   300.000000   300.00
# Google Phone                    600.00   601.892744  1200.00
# LG Dryer                        600.00   600.000000   600.00
# LG Washing Machine              600.00   600.000000   600.00
# Lightning Charging Cable         14.95    16.111845    44.85
# Macbook Pro Laptop             1700.00  1700.000000  1700.00
# ...
